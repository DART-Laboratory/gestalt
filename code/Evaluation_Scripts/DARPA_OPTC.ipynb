# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import torch
from torch_geometric.data import Data
import torch.nn.functional as F
import warnings
import os
warnings.filterwarnings('ignore')
from torch_geometric.loader import NeighborLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# %matplotlib inline

# %%
num_of_ctg = 10
learning_rounds = 3
epochs = 10
hosts = ['051.txt','501.txt','201.txt']

# %%
from pprint import pprint
import json
import copy

import gensim
from gensim.models import Word2Vec
from multiprocessing import Pool
from itertools import compress
from tqdm import tqdm
import time

import multiprocessing
import random

# %%
import gensim
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from collections import Counter
from gensim.models import Word2Vec
from multiprocessing import Pool
from itertools import compress
from tqdm import tqdm
import time

def infer(doc,word2vec):  
    word_emb = []
    for word in doc:
        if word in word2vec.wv:
            word_emb.append(word2vec.wv[word])
            
    if len(word_emb) == 0:
        return np.zeros(20)

    out_emb = torch.tensor(word_emb,dtype=torch.float)
    out_emb = out_emb.detach().cpu().numpy()
    out_emb = np.mean(out_emb,axis=0)
    return out_emb

# %%
def preprocess(data):
    new_data = {}
    for x in data:
        check1 = x['object'] in ['PROCESS','FILE','FLOW','MODULE']
        check2 = not (x['action'] in ['START','TERMINATE'])
        check3 = x['actorID'] != x['objectID']
        key = (x['action'],x['actorID'],x['objectID'],x['object'],x['pid'],x['ppid'])
        if check1 and check2 and check3:
            new_data[key] = x
    return list(new_data.values())

# %%
def Extract_Semantic_Info(event):
    object_type = event['object']
    properties = event['properties']

    label_mapping = {
        "PROCESS": ('parent_image_path', 'image_path'),
        "FILE": ('image_path', 'file_path'),
        "MODULE": ('image_path', 'module_path'),
        "FLOW": ('image_path', 'dest_ip', 'dest_port')
    }

    label_keys = label_mapping.get(object_type, None)
    if label_keys:
        labels = [properties.get(key) for key in label_keys]
        if all(labels):
            event["actorname"], event["objectname"] = labels[0], ' '.join(labels[1:])
            return event
    return None

# %%
def describe(x):
    action = x["action"]
    props = x['properties']
    typ = x['object']

    phrase = ''
    try:
        if typ == 'PROCESS':
            phrase = f"{props['parent_image_path']} {action} {props['image_path']} {props['command_line']}" 

        elif typ == 'FILE':
            phrase = f"{props['image_path']} {action} {props['file_path']}"    

        elif typ == 'FLOW':
            phrase = f"{props['image_path']} {action}  {props['dest_ip']} {props['dest_port']} {props['direction']}"    

        else:
            phrase = f"{props['image_path']} {action} {props['module_path']}"
    except:
        phrase = ''
  
    return phrase.split(' ')

# %%
def transform(text):
    text = [event for event in (Extract_Semantic_Info(x) for x in text) if event]
    data = preprocess(text)

    temp = [describe(x) for x in data]
    temp = [x for x in temp if len(x) != 0]

    for i in range(len(data)):
        data[i]['phrase'] = temp[i]
        try:
            data[i]['proc_name'] = data[i]['properties']['image_path']
        except:
            data[i]['proc_name'] = ''

    df = pd.DataFrame.from_dict(data)
    df['timestamp'] = df['timestamp'].str[:-6]
    df['timestamp'] = pd.to_datetime(df['timestamp'],infer_datetime_format=True)
    df.sort_values(by='timestamp', ascending=True,inplace=True)

    return df

def load_data(dataset_id):
    f = open(f"content/data/hosts/{dataset_id}")
    content = [json.loads(line) for line in f]
    return prepare_graph(transform(content))

# %%
def prepare_graph(df):
    nodes = {}
    labels = {}
    edges = []
    proc = {}
    dummies = {'PROCESS':0,'FLOW':1,'FILE':2,'MODULE':3}

    for i in range(len(df)):
        x = df.iloc[i]

        actorid = x['actorID']
        if not (actorid in nodes):
            nodes[actorid] = []
        nodes[actorid] += x['phrase']
        labels[actorid] = dummies['PROCESS']

        objectid = x["objectID"]
        if not (objectid in nodes):
            nodes[objectid] = []
        nodes[objectid] += x['phrase']
        labels[objectid] = dummies[x['object']]
        
        edges.append(( actorid, objectid, x['action'] ))
        
        proc[actorid] = x['proc_name']

    features = []
    feat_labels = []
    edge_index = [[],[]]
    index  = {}
    mapp = []
    
    all_procs = set()
              
    for k,v in nodes.items():
        features.append(v)
        feat_labels.append(labels[k])
        index[k] = len(features) - 1
        mapp.append(k)
        
        if k in proc:
            all_procs.add(proc[k])

    for x in edges:
        src = index[x[0]]
        dst = index[x[1]]
    
        edge_index[0].append(src)
        edge_index[1].append(dst)    
    
    idx_to_proc = {}
    for i in range(len(mapp)):
        if mapp[i] in proc:
            idx_to_proc[i] = proc[mapp[i]]
            
    all_procs = list(all_procs)
    
    return features,feat_labels,edge_index,mapp,all_procs,idx_to_proc

# %%
from torch_geometric.nn import GCNConv
from torch_geometric.nn import SAGEConv, GATConv
import torch.nn.functional as F
import torch.nn as nn

class GCN(torch.nn.Module):
    def __init__(self):
        super(GCN, self).__init__()
        self.conv1 = SAGEConv(20, 32, normalize=True)
        self.conv2 = SAGEConv(32, 20, normalize=True)
        self.linear = nn.Linear(in_features=20, out_features=4)

    def forward(self, x: torch.Tensor, edge_index: torch.Tensor) -> torch.Tensor:
    
        x = self.encode(x, edge_index)
        x = self.linear(x)
        return F.softmax(x, dim=1)
    
    def encode(self, x: torch.Tensor, edge_index: torch.Tensor) -> torch.Tensor:
        
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index)
        return x
    
    def freeze_conv_layers(self):
        for param in self.conv1.parameters():
            param.requires_grad = False
        for param in self.conv2.parameters():
            param.requires_grad = False

# %%
from gensim.models.callbacks import CallbackAny2Vec
import gensim
from gensim.models import Word2Vec
from multiprocessing import Pool
from itertools import compress
from tqdm import tqdm
import time

class EpochSaver(CallbackAny2Vec):

    def __init__(self,client_id):
        self.epoch = 0
        self.cid = client_id

    def on_epoch_end(self, model):
        model.save(f"Content_FL_Exp/{self.cid}.model")
        self.epoch += 1
        
class EpochLogger(CallbackAny2Vec):

    def __init__(self):
        self.epoch = 0

    def on_epoch_begin(self, model):
        pass
        #print("Epoch #{} start".format(self.epoch))

    def on_epoch_end(self, model):
        #print("Epoch #{} end".format(self.epoch))
        self.epoch += 1
        
def train_word2vec_func(docs,client_id):
    logger = EpochLogger()
    saver = EpochSaver(client_id)
    word2vec = Word2Vec(sentences=docs, vector_size=20, window=5, min_count=1,workers=5,epochs=100,callbacks=[saver,logger])

# %%
def init_gnns():
    global num_of_ctg
    n = num_of_ctg
    gnn_models = []
    for i in range(n):
        m = GCN().to(device)
        gnn_models.append(m)
    return gnn_models

# %%
def define_categories(pids):
    global num_of_ctg
    n = num_of_ctg - 1
    ctg = set(pids)
    ctg = list(ctg)
    k, m = divmod(len(ctg), n)
    return [set(ctg[i * k + min(i, m):(i + 1) * k + min(i + 1, m)]) for i in range(n)]

# %%
def map_pids_to_category_indices(pids, categories):
    pid_to_category_index = {}
    
    for pid in pids:
        for category_index, category_set in enumerate(categories):
            if pid in category_set:
                pid_to_category_index[pid] = category_index
                break 
    
    return pid_to_category_index

# %%
procs_total = []
data_cache = {}
categories = None

def load_clients_data(client_ids):
    
    global data_cache,categories,procs_total
    
    for x in client_ids:
        docs,labels,edges,mapp,pids,idx_to_pid = load_data(x)
        data_cache[x] = [docs,labels,edges,mapp,pids,idx_to_pid]
        procs_total = procs_total + pids
        
    categories = define_categories(procs_total)

# %%
from torch.nn import CrossEntropyLoss
from sklearn.utils import class_weight
import copy

templates = init_gnns()

def train_gnn_func(nodes,labels,edges,mapp,pids,idx_to_pid):
    
    global categories ,epochs
    
    pid_to_gnn_index = map_pids_to_category_indices(pids, categories)
    
    set_pids = set(pids)

    proc_index = list(idx_to_pid.keys())

    train_splits = [[] for _ in range(len(categories))]
    
    for i in proc_index:
        pname = idx_to_pid[str(i)]
        split_indx = pid_to_gnn_index[pname]
        train_splits[split_indx].append(int(i))
        
    local_models = [copy.deepcopy(x) for x in templates]
    
    for i in range(len(local_models)-1):
            
        if len(train_splits[i]) == 0:
            local_models[i] = None
        else:
            if f"global{i}.pth" in os.listdir("Content_FL_Exp"):
                local_models[i].load_state_dict(torch.load(f"Content_FL_Exp/global{i}.pth"))

            optimizer = torch.optim.Adam(local_models[i].parameters(), lr=0.01, weight_decay=5e-4)
            criterion = CrossEntropyLoss()

            graph = Data(x=torch.tensor(nodes,dtype=torch.float).to(device),y=torch.tensor(labels,dtype=torch.long).to(device), edge_index=torch.tensor(edges,dtype=torch.long).to(device))
            mask = torch.tensor([False]*graph.num_nodes, dtype=torch.bool)
            mask[train_splits[i]] = True
            
            def get_neighbors(edge_index, nodes):
                neighbors = []
                for node in nodes:
                    mask = edge_index[0] == node
                    neighbors.extend(edge_index[1, mask].tolist())
                return torch.tensor(list(set(neighbors)), dtype=torch.long)

            one_hop_neighbors = get_neighbors(graph.edge_index, train_splits[i])
            two_hop_neighbors = get_neighbors(graph.edge_index, one_hop_neighbors)
            two_hop_neighbors = two_hop_neighbors[~mask[two_hop_neighbors]]
            mask[two_hop_neighbors] = True
            
            for epoch in range(epochs):
                print(f'Training GNN Category {i} Model for Epoch {epoch}')

                loader = NeighborLoader(graph, num_neighbors=[-1,-1], batch_size=5000,input_nodes=mask)
                total_loss = 0
                for subg in loader:
                    local_models[i].train()
                    optimizer.zero_grad() 
                    out = local_models[i](subg.x, subg.edge_index) 
                    loss = criterion(out, subg.y) 
                    loss.backward() 
                    optimizer.step()      
                    total_loss += loss.item() * subg.batch_size
                print("Loss: ", total_loss / mask.sum().item(), '\n')
    
    graph = Data(x=torch.tensor(nodes,dtype=torch.float).to(device),y=torch.tensor(labels,dtype=torch.long).to(device), edge_index=torch.tensor(edges,dtype=torch.long).to(device))
    optimizer = torch.optim.Adam(local_models[-1].parameters(), lr=0.01, weight_decay=5e-4)
    criterion = CrossEntropyLoss()
    
    for epoch in range(epochs):
        print(f'Training Catch all GNN Category Model for Epoch {epoch}')    
        local_models[-1].train()
        optimizer.zero_grad() 
        out = local_models[-1](graph.x, graph.edge_index) 
        loss = criterion(out, graph.y) 
        loss.backward() 
        optimizer.step()      
        print(f"Epoch: {epoch}, Loss: {loss.item()}")

    return local_models

# %%
def client_handling_loop(client_id):
    print(f"Running Setup on Client {client_id} \n")
    
    docs,labels,edges,mapp,pids,idx_to_pid = data_cache[client_id]
    
    nodes_feat = []
    word2vec = Word2Vec.load(f"Content_FL_Exp/unified_word2vec.model")
    for x in docs:
        nodes_feat.append( infer(x,word2vec) ) 
        
    trained_local_models = train_gnn_func(nodes_feat,labels,edges,mapp,pids,idx_to_pid)
    return trained_local_models

# %%
import random
def perform_federated_learning(n_clients):
    client_models = []
    for c in n_clients:
        local_gnns = client_handling_loop(c)
        client_models.append(local_gnns)
    return client_models

# %%
def server_aggregate(all_models):
    global_models = copy.deepcopy(templates)
    
    for l in range(len(all_models)):
        
        current_models = all_models[l]
        current_models = [x for x in current_models if x != None]
        
        if not len(current_models) == 0:
        
            global_dict = global_models[l].state_dict()

            for k in global_dict.keys():
                param_list = [current_models[i].state_dict()[k] for i in range(len(current_models))]
                global_dict[k] = torch.stack(param_list, 0).mean(0)

            global_models[l].load_state_dict(global_dict)
            torch.save(global_models[l].state_dict(), f"Content_FL_Exp/global{l}.pth")
                   
    return global_models

# %%
from itertools import compress

# %%
def helper(MP,acts,objs,GP,edges,mapp):

    all_pids = acts.union(objs)
    GN = all_pids - GP
    MN = all_pids - MP

    TP = MP.intersection(GP)
    FP = MP.intersection(GN)
    FN = MN.intersection(GP)
    
    two_hop_gp = construct_neighborhood(GP,mapp,edges,2)
    two_hop_tp = construct_neighborhood(TP,mapp,edges,2)
    FP = FP - two_hop_gp
    TP = TP.union(FN.intersection(two_hop_tp))
    FN = FN - two_hop_tp

    TP,FPC,FN = len(TP),len(FP),len(FN)
    
    TN = (len(acts) + len(objs)) - TP - FPC - FN
    
    FPR = FPC / (FPC+TN)
    TPR = TP / (TP+FN)
    
    return TP,FPC,FN,TN,FP

# %%
from itertools import compress
from torch_geometric import utils

def construct_neighborhood(ids,mapp,edges,hops):
    if hops == 0:
        return set()
    else:
        neighbors = set()
        for i in range(len(edges[0])):
            if mapp[edges[0][i]] in ids:
                neighbors.add(mapp[edges[1][i]])
            if mapp[edges[1][i]] in ids:
                neighbors.add(mapp[edges[0][i]])
        return neighbors.union( construct_neighborhood(neighbors,mapp,edges,hops-1) )

# %%
#!rm Content_FL_Exp/global*.pth

# %%
#load_clients_data(hosts)

# %%
with open('Content_FL_Exp/optc_ensemble_ben.json', 'r') as f:
    data_cache = json.load(f)

proc_total = []
for x in ['051.txt','501.txt','201.txt']:
    proc_total = proc_total + data_cache[x][-2]
    
categories = define_categories(proc_total)

# %%
import random

for r in range(learning_rounds):
    print(f"Federated Learning Round Number: {r}\n")
    client_models = perform_federated_learning(hosts)
    arranged_models =  [list(group) for group in zip(*client_models)]
    global_models = server_aggregate(arranged_models)
# Out:
# Federated Learning Round Number: 0
#
# Running Setup on Client 051.txt
#
# Training GNN Category 0 Model for Epoch 0
# Loss:  1.1607321704938873
#
# Training GNN Category 0 Model for Epoch 1
# Loss:  0.9706307364878907
#
# Training GNN Category 0 Model for Epoch 2
# Loss:  0.8888539659892213
#
# Training GNN Category 0 Model for Epoch 3
# Loss:  0.8541955431182546
#
# Training GNN Category 0 Model for Epoch 4
# Loss:  0.83182222949231
#
# Training GNN Category 0 Model for Epoch 5
# Loss:  0.8172051407419264
#
# Training GNN Category 0 Model for Epoch 6
# Loss:  0.8060187359903456
#
# Training GNN Category 0 Model for Epoch 7
# Loss:  0.7982049407577885
#
# Training GNN Category 0 Model for Epoch 8
# Loss:  0.7943486545631363
#
# Training GNN Category 0 Model for Epoch 9
# Loss:  0.7929759723251105
#
# Training GNN Category 1 Model for Epoch 0
# Loss:  1.3833585586618566
#
# Training GNN Category 1 Model for Epoch 1
# Loss:  1.3459108886980178
#
# Training GNN Category 1 Model for Epoch 2
# Loss:  1.3179822166559871
#
# Training GNN Category 1 Model for Epoch 3
# Loss:  1.2901237208097789
#
# Training GNN Category 1 Model for Epoch 4
# Loss:  1.2647519192525798
#
# Training GNN Category 1 Model for Epoch 5
# Loss:  1.2409667639421111
#
# Training GNN Category 1 Model for Epoch 6
# Loss:  1.2154723257177962
#
# Training GNN Category 1 Model for Epoch 7
# Loss:  1.1878853490708612
#
# Training GNN Category 1 Model for Epoch 8
# Loss:  1.1654313903299025
#
# Training GNN Category 1 Model for Epoch 9
# Loss:  1.1397363170587993
#
# Training GNN Category 2 Model for Epoch 0
# Loss:  1.1727056279482468
#
# Training GNN Category 2 Model for Epoch 1
# Loss:  0.9875725503348787
#
# Training GNN Category 2 Model for Epoch 2
# Loss:  0.9051958491321325
#
# Training GNN Category 2 Model for Epoch 3
# Loss:  0.8692732418430476
#
# Training GNN Category 2 Model for Epoch 4
# Loss:  0.8498015002326275
#
# Training GNN Category 2 Model for Epoch 5
# Loss:  0.8349811498464327
#
# Training GNN Category 2 Model for Epoch 6
# Loss:  0.8264438852086338
#
# Training GNN Category 2 Model for Epoch 7
# Loss:  0.812088757719411
#
# Training GNN Category 2 Model for Epoch 8
# Loss:  0.8030687839360963
#
# Training GNN Category 2 Model for Epoch 9
# Loss:  0.7971505494292352
#
# Training GNN Category 3 Model for Epoch 0
# Loss:  1.2184438299841682
#
# Training GNN Category 3 Model for Epoch 1
# Loss:  1.0056803043734466
#
# Training GNN Category 3 Model for Epoch 2
# Loss:  0.9061181420046048
#
# Training GNN Category 3 Model for Epoch 3
# Loss:  0.8684936402970929
#
# Training GNN Category 3 Model for Epoch 4
# Loss:  0.8462495088000298
#
# Training GNN Category 3 Model for Epoch 5
# Loss:  0.8292695130776921
#
# Training GNN Category 3 Model for Epoch 6
# Loss:  0.8161431798302506
#
# Training GNN Category 3 Model for Epoch 7
# Loss:  0.8057292320217984
#
# Training GNN Category 3 Model for Epoch 8
# Loss:  0.7977229411750311
#
# Training GNN Category 3 Model for Epoch 9
# Loss:  0.7914570300752851
#
# Training GNN Category 4 Model for Epoch 0
# Loss:  1.3884300287165123
#
# Training GNN Category 4 Model for Epoch 1
# Loss:  1.3528555797257722
#
# Training GNN Category 4 Model for Epoch 2
# Loss:  1.3244625591613932
#
# Training GNN Category 4 Model for Epoch 3
# Loss:  1.3013777974021834
#
# Training GNN Category 4 Model for Epoch 4
# Loss:  1.2798813106192672
#
# Training GNN Category 4 Model for Epoch 5
# Loss:  1.2527299323306766
#
# Training GNN Category 4 Model for Epoch 6
# Loss:  1.2273206563804286
#
# Training GNN Category 4 Model for Epoch 7
# Loss:  1.2024071922608923
#
# Training GNN Category 4 Model for Epoch 8
# Loss:  1.1764255267845032
#
# Training GNN Category 4 Model for Epoch 9
# Loss:  1.153340907830802
#
# Training GNN Category 5 Model for Epoch 0
# Loss:  1.215839483040624
#
# Training GNN Category 5 Model for Epoch 1
# Loss:  0.9915637828907896
#
# Training GNN Category 5 Model for Epoch 2
# Loss:  0.8895621753956076
#
# Training GNN Category 5 Model for Epoch 3
# Loss:  0.8519533737500976
#
# Training GNN Category 5 Model for Epoch 4
# Loss:  0.8326704178719929
#
# Training GNN Category 5 Model for Epoch 5
# Loss:  0.8174503320863246
#
# Training GNN Category 5 Model for Epoch 6
# Loss:  0.8068788144291622
#
# Training GNN Category 5 Model for Epoch 7
# Loss:  0.7981511466483372
#
# Training GNN Category 5 Model for Epoch 8
# Loss:  0.79507882350516
#
# Training GNN Category 5 Model for Epoch 9
# Loss:  0.7900683724136344
#
# Training GNN Category 6 Model for Epoch 0
# Loss:  1.286122391386551
#
# Training GNN Category 6 Model for Epoch 1
# Loss:  1.0632931208171426
#
# Training GNN Category 6 Model for Epoch 2
# Loss:  0.9236661810795784
#
# Training GNN Category 6 Model for Epoch 3
# Loss:  0.8695548401519658
#
# Training GNN Category 6 Model for Epoch 4
# Loss:  0.8419739587385264
#
# Training GNN Category 6 Model for Epoch 5
# Loss:  0.8270351638378526
#
# Training GNN Category 6 Model for Epoch 6
# Loss:  0.8138082537465596
#
# Training GNN Category 6 Model for Epoch 7
# Loss:  0.8052808495488266
#
# Training GNN Category 6 Model for Epoch 8
# Loss:  0.7999567135628622
#
# Training GNN Category 6 Model for Epoch 9
# Loss:  0.7973770656745159
#
# Training GNN Category 7 Model for Epoch 0
# Loss:  1.1991606336357956
#
# Training GNN Category 7 Model for Epoch 1
# Loss:  0.9999871164779908
#
# Training GNN Category 7 Model for Epoch 2
# Loss:  0.9068122201669332
#
# Training GNN Category 7 Model for Epoch 3
# Loss:  0.8685648342520793
#
# Training GNN Category 7 Model for Epoch 4
# Loss:  0.8471999320186051
#
# Training GNN Category 7 Model for Epoch 5
# Loss:  0.8287842275323352
#
# Training GNN Category 7 Model for Epoch 6
# Loss:  0.8181523499938718
#
# Training GNN Category 7 Model for Epoch 7
# Loss:  0.8049619270418482
#
# Training GNN Category 7 Model for Epoch 8
# Loss:  0.7994613765667129
#
# Training GNN Category 7 Model for Epoch 9
# Loss:  0.7932167254526605
#
# Training GNN Category 8 Model for Epoch 0
# Loss:  1.165719740544592
#
# Training GNN Category 8 Model for Epoch 1
# Loss:  0.9677882313613002
#
# Training GNN Category 8 Model for Epoch 2
# Loss:  0.8957659873374095
#
# Training GNN Category 8 Model for Epoch 3
# Loss:  0.8623802062085887
#
# Training GNN Category 8 Model for Epoch 4
# Loss:  0.8366922025428272
#
# Training GNN Category 8 Model for Epoch 5
# Loss:  0.8193635400774474
#
# Training GNN Category 8 Model for Epoch 6
# Loss:  0.8076731359207786
#
# Training GNN Category 8 Model for Epoch 7
# Loss:  0.7990075746302
#
# Training GNN Category 8 Model for Epoch 8
# Loss:  0.7946938128364299
#
# Training GNN Category 8 Model for Epoch 9
# Loss:  0.7912956387831933
#
# Training Catch all GNN Category Model for Epoch 0
# Epoch: 0, Loss: 1.4035978317260742
# Training Catch all GNN Category Model for Epoch 1
# Epoch: 1, Loss: 1.352125644683838
# Training Catch all GNN Category Model for Epoch 2
# Epoch: 2, Loss: 1.305652379989624
# Training Catch all GNN Category Model for Epoch 3
# Epoch: 3, Loss: 1.290665864944458
# Training Catch all GNN Category Model for Epoch 4
# Epoch: 4, Loss: 1.266100525856018
# Training Catch all GNN Category Model for Epoch 5
# Epoch: 5, Loss: 1.2555969953536987
# Training Catch all GNN Category Model for Epoch 6
# Epoch: 6, Loss: 1.231133222579956
# Training Catch all GNN Category Model for Epoch 7
# Epoch: 7, Loss: 1.2158468961715698
# Training Catch all GNN Category Model for Epoch 8
# Epoch: 8, Loss: 1.1932255029678345
# Training Catch all GNN Category Model for Epoch 9
# Epoch: 9, Loss: 1.1749298572540283
# Running Setup on Client 501.txt
#
# Training GNN Category 0 Model for Epoch 0
# Loss:  1.059663633301209
#
# Training GNN Category 0 Model for Epoch 1
# Loss:  0.838855847755151
#
# Training GNN Category 0 Model for Epoch 2
# Loss:  0.7975055839542124
#
# Training GNN Category 0 Model for Epoch 3
# Loss:  0.7833466643321085
#
# Training GNN Category 0 Model for Epoch 4
# Loss:  0.7752181054222819
#
# Training GNN Category 0 Model for Epoch 5
# Loss:  0.7691112628182996
#
# Training GNN Category 0 Model for Epoch 6
# Loss:  0.7673679787850064
#
# Training GNN Category 0 Model for Epoch 7
# Loss:  0.7633885459578474
#
# Training GNN Category 0 Model for Epoch 8
# Loss:  0.7626467013916265
#
# Training GNN Category 0 Model for Epoch 9
# Loss:  0.7643543108873393
#
# Training GNN Category 1 Model for Epoch 0
# Loss:  1.3567037002269167
#
# Training GNN Category 1 Model for Epoch 1
# Loss:  1.2834329211275608
#
# Training GNN Category 1 Model for Epoch 2
# Loss:  1.2176827773613934
#
# Training GNN Category 1 Model for Epoch 3
# Loss:  1.159885764004097
#
# Training GNN Category 1 Model for Epoch 4
# Loss:  1.1097205199308613
#
# Training GNN Category 1 Model for Epoch 5
# Loss:  1.0694173116948082
#
# Training GNN Category 1 Model for Epoch 6
# Loss:  1.0285095265310196
#
# Training GNN Category 1 Model for Epoch 7
# Loss:  1.0061461420842142
#
# Training GNN Category 1 Model for Epoch 8
# Loss:  0.96641020204146
#
# Training GNN Category 1 Model for Epoch 9
# Loss:  0.9354346508324205
#
# Training GNN Category 2 Model for Epoch 0
# Loss:  1.327616086380993
#
# Training GNN Category 2 Model for Epoch 1
# Loss:  1.196098481109231
#
# Training GNN Category 2 Model for Epoch 2
# Loss:  1.0769667541658783
#
# Training GNN Category 2 Model for Epoch 3
# Loss:  0.98946458300254
#
# Training GNN Category 2 Model for Epoch 4
# Loss:  0.9292723154313436
#
# Training GNN Category 2 Model for Epoch 5
# Loss:  0.8786441603090924
#
# Training GNN Category 2 Model for Epoch 6
# Loss:  0.8436353160428237
#
# Training GNN Category 2 Model for Epoch 7
# Loss:  0.8207802696144844
#
# Training GNN Category 2 Model for Epoch 8
# Loss:  0.8051412100006362
#
# Training GNN Category 2 Model for Epoch 9
# Loss:  0.797964086191255
#
# Training GNN Category 3 Model for Epoch 0
# Loss:  1.337033353100397
#
# Training GNN Category 3 Model for Epoch 1
# Loss:  1.210833400423895
#
# Training GNN Category 3 Model for Epoch 2
# Loss:  1.085255352358759
#
# Training GNN Category 3 Model for Epoch 3
# Loss:  0.9781868920691691
#
# Training GNN Category 3 Model for Epoch 4
# Loss:  0.9107808523190787
#
# Training GNN Category 3 Model for Epoch 5
# Loss:  0.8586739751797179
#
# Training GNN Category 3 Model for Epoch 6
# Loss:  0.8273824877791226
#
# Training GNN Category 3 Model for Epoch 7
# Loss:  0.8127287441913748
#
# Training GNN Category 3 Model for Epoch 8
# Loss:  0.7997174008127916
#
# Training GNN Category 3 Model for Epoch 9
# Loss:  0.7907782915341846
#
# Training GNN Category 4 Model for Epoch 0
# Loss:  1.3179758588450259
#
# Training GNN Category 4 Model for Epoch 1
# Loss:  1.1648556506026804
#
# Training GNN Category 4 Model for Epoch 2
# Loss:  1.0128652066846384
#
# Training GNN Category 4 Model for Epoch 3
# Loss:  0.9082935081199232
#
# Training GNN Category 4 Model for Epoch 4
# Loss:  0.8488697154884236
#
# Training GNN Category 4 Model for Epoch 5
# Loss:  0.8187020908215236
#
# Training GNN Category 4 Model for Epoch 6
# Loss:  0.8028717448834485
#
# Training GNN Category 4 Model for Epoch 7
# Loss:  0.7942594665529782
#
# Training GNN Category 4 Model for Epoch 8
# Loss:  0.7884288130352248
#
# Training GNN Category 4 Model for Epoch 9
# Loss:  0.78575957974021
#
# Training GNN Category 5 Model for Epoch 0
# Loss:  1.305993985056859
#
# Training GNN Category 5 Model for Epoch 1
# Loss:  1.1597746554433137
#
# Training GNN Category 5 Model for Epoch 2
# Loss:  1.0311771122436335
#
# Training GNN Category 5 Model for Epoch 3
# Loss:  0.9408496647382035
#
# Training GNN Category 5 Model for Epoch 4
# Loss:  0.8817194378095881
#
# Training GNN Category 5 Model for Epoch 5
# Loss:  0.844208793410543
#
# Training GNN Category 5 Model for Epoch 6
# Loss:  0.8211905841654557
#
# Training GNN Category 5 Model for Epoch 7
# Loss:  0.8076505166761814
#
# Training GNN Category 5 Model for Epoch 8
# Loss:  0.7990125708363239
#
# Training GNN Category 5 Model for Epoch 9
# Loss:  0.792329468067625
#
# Training GNN Category 6 Model for Epoch 0
# Loss:  1.3068940759868743
#
# Training GNN Category 6 Model for Epoch 1
# Loss:  1.1577949155450977
#
# Training GNN Category 6 Model for Epoch 2
# Loss:  1.0191760197186541
#
# Training GNN Category 6 Model for Epoch 3
# Loss:  0.922744724568087
#
# Training GNN Category 6 Model for Epoch 4
# Loss:  0.8631260077265608
#
# Training GNN Category 6 Model for Epoch 5
# Loss:  0.829065539038945
#
# Training GNN Category 6 Model for Epoch 6
# Loss:  0.8071520751966821
#
# Training GNN Category 6 Model for Epoch 7
# Loss:  0.7971453634453826
#
# Training GNN Category 6 Model for Epoch 8
# Loss:  0.7900156754041967
#
# Training GNN Category 6 Model for Epoch 9
# Loss:  0.7850801402185282
#
# Training GNN Category 7 Model for Epoch 0
# Loss:  1.3241796127387329
#
# Training GNN Category 7 Model for Epoch 1
# Loss:  1.1862632749353261
#
# Training GNN Category 7 Model for Epoch 2
# Loss:  1.046747795148298
#
# Training GNN Category 7 Model for Epoch 3
# Loss:  0.9488226909145195
#
# Training GNN Category 7 Model for Epoch 4
# Loss:  0.8884534849642953
#
# Training GNN Category 7 Model for Epoch 5
# Loss:  0.845022069276813
#
# Training GNN Category 7 Model for Epoch 6
# Loss:  0.8201857055631109
#
# Training GNN Category 7 Model for Epoch 7
# Loss:  0.8073043532361862
#
# Training GNN Category 7 Model for Epoch 8
# Loss:  0.7959254646411256
#
# Training GNN Category 7 Model for Epoch 9
# Loss:  0.7884367290358949
#
# Training GNN Category 8 Model for Epoch 0
# Loss:  1.2972822633278212
#
# Training GNN Category 8 Model for Epoch 1
# Loss:  1.1233506985441288
#
# Training GNN Category 8 Model for Epoch 2
# Loss:  0.9881803904399579
#
# Training GNN Category 8 Model for Epoch 3
# Loss:  0.9194901907762988
#
# Training GNN Category 8 Model for Epoch 4
# Loss:  0.8830468681835716
#
# Training GNN Category 8 Model for Epoch 5
# Loss:  0.8531269250770036
#
# Training GNN Category 8 Model for Epoch 6
# Loss:  0.8282980184533462
#
# Training GNN Category 8 Model for Epoch 7
# Loss:  0.8087724513210304
#
# Training GNN Category 8 Model for Epoch 8
# Loss:  0.7975342908539071
#
# Training GNN Category 8 Model for Epoch 9
# Loss:  0.7917984593908479
#
# Training Catch all GNN Category Model for Epoch 0
# Epoch: 0, Loss: 1.4022164344787598
# Training Catch all GNN Category Model for Epoch 1
# Epoch: 1, Loss: 1.3464568853378296
# Training Catch all GNN Category Model for Epoch 2
# Epoch: 2, Loss: 1.3113199472427368
# Training Catch all GNN Category Model for Epoch 3
# Epoch: 3, Loss: 1.2920070886611938
# Training Catch all GNN Category Model for Epoch 4
# Epoch: 4, Loss: 1.2807868719100952
# Training Catch all GNN Category Model for Epoch 5
# Epoch: 5, Loss: 1.27017080783844
# Training Catch all GNN Category Model for Epoch 6
# Epoch: 6, Loss: 1.2473880052566528
# Training Catch all GNN Category Model for Epoch 7
# Epoch: 7, Loss: 1.233794927597046
# Training Catch all GNN Category Model for Epoch 8
# Epoch: 8, Loss: 1.2149031162261963
# Training Catch all GNN Category Model for Epoch 9
# Epoch: 9, Loss: 1.2054616212844849
# Running Setup on Client 201.txt
#
# Training GNN Category 0 Model for Epoch 0
# Loss:  0.9812108182826149
#
# Training GNN Category 0 Model for Epoch 1
# Loss:  0.7941817903300621
#
# Training GNN Category 0 Model for Epoch 2
# Loss:  0.7752462231387228
#
# Training GNN Category 0 Model for Epoch 3
# Loss:  0.7703492552741386
#
# Training GNN Category 0 Model for Epoch 4
# Loss:  0.7727480447482638
#
# Training GNN Category 0 Model for Epoch 5
# Loss:  0.7630262050079214
#
# Training GNN Category 0 Model for Epoch 6
# Loss:  0.7620046017951363
#
# Training GNN Category 0 Model for Epoch 7
# Loss:  0.761823995737378
#
# Training GNN Category 0 Model for Epoch 8
# Loss:  0.7616615639533579
#
# Training GNN Category 0 Model for Epoch 9
# Loss:  0.7623297050581003
#
# Training GNN Category 1 Model for Epoch 0
# Loss:  1.035547403399957
#
# Training GNN Category 1 Model for Epoch 1
# Loss:  0.802848685947893
#
# Training GNN Category 1 Model for Epoch 2
# Loss:  0.7771972415607044
#
# Training GNN Category 1 Model for Epoch 3
# Loss:  0.7700699652480021
#
# Training GNN Category 1 Model for Epoch 4
# Loss:  0.7700690960133584
#
# Training GNN Category 1 Model for Epoch 5
# Loss:  0.7666307170013921
#
# Training GNN Category 1 Model for Epoch 6
# Loss:  0.7633478110086055
#
# Training GNN Category 1 Model for Epoch 7
# Loss:  0.7651643154968705
#
# Training GNN Category 1 Model for Epoch 8
# Loss:  0.7627181069795341
#
# Training GNN Category 1 Model for Epoch 9
# Loss:  0.7625165675314804
#
# Training GNN Category 2 Model for Epoch 0
# Loss:  1.2310010635616377
#
# Training GNN Category 2 Model for Epoch 1
# Loss:  0.9788466679094733
#
# Training GNN Category 2 Model for Epoch 2
# Loss:  0.8584205207640404
#
# Training GNN Category 2 Model for Epoch 3
# Loss:  0.816325744363255
#
# Training GNN Category 2 Model for Epoch 4
# Loss:  0.7992686275808468
#
# Training GNN Category 2 Model for Epoch 5
# Loss:  0.786449760951194
#
# Training GNN Category 2 Model for Epoch 6
# Loss:  0.7815220763670667
#
# Training GNN Category 2 Model for Epoch 7
# Loss:  0.7759631610482877
#
# Training GNN Category 2 Model for Epoch 8
# Loss:  0.7722997315417818
#
# Training GNN Category 2 Model for Epoch 9
# Loss:  0.7698981757221608
#
# Training GNN Category 3 Model for Epoch 0
# Loss:  1.23424030633236
#
# Training GNN Category 3 Model for Epoch 1
# Loss:  0.9679963243129597
#
# Training GNN Category 3 Model for Epoch 2
# Loss:  0.8443741409777547
#
# Training GNN Category 3 Model for Epoch 3
# Loss:  0.8029522082313167
#
# Training GNN Category 3 Model for Epoch 4
# Loss:  0.7893991739056051
#
# Training GNN Category 3 Model for Epoch 5
# Loss:  0.7776604364759273
#
# Training GNN Category 3 Model for Epoch 6
# Loss:  0.7718227139382807
#
# Training GNN Category 3 Model for Epoch 7
# Loss:  0.7686273298380766
#
# Training GNN Category 3 Model for Epoch 8
# Loss:  0.7707007775714992
#
# Training GNN Category 3 Model for Epoch 9
# Loss:  0.7689071702756548
#
# Training GNN Category 4 Model for Epoch 0
# Loss:  1.0241247831294478
#
# Training GNN Category 4 Model for Epoch 1
# Loss:  0.7998242595714632
#
# Training GNN Category 4 Model for Epoch 2
# Loss:  0.7732535021809803
#
# Training GNN Category 4 Model for Epoch 3
# Loss:  0.7657386314428398
#
# Training GNN Category 4 Model for Epoch 4
# Loss:  0.7641136383002597
#
# Training GNN Category 4 Model for Epoch 5
# Loss:  0.7633714158974705
#
# Training GNN Category 4 Model for Epoch 6
# Loss:  0.7609719295003512
#
# Training GNN Category 4 Model for Epoch 7
# Loss:  0.7624680736550392
#
# Training GNN Category 4 Model for Epoch 8
# Loss:  0.7614313116109598
#
# Training GNN Category 4 Model for Epoch 9
# Loss:  0.7611815732859211
#
# Training GNN Category 5 Model for Epoch 0
# Loss:  1.0084731243975142
#
# Training GNN Category 5 Model for Epoch 1
# Loss:  0.7995401904452208
#
# Training GNN Category 5 Model for Epoch 2
# Loss:  0.7773049391843244
#
# Training GNN Category 5 Model for Epoch 3
# Loss:  0.7714306789695118
#
# Training GNN Category 5 Model for Epoch 4
# Loss:  0.7669391641977052
#
# Training GNN Category 5 Model for Epoch 5
# Loss:  0.779439513590147
#
# Training GNN Category 5 Model for Epoch 6
# Loss:  0.7656348434709943
#
# Training GNN Category 5 Model for Epoch 7
# Loss:  0.7606611214262803
#
# Training GNN Category 5 Model for Epoch 8
# Loss:  0.760366921320395
#
# Training GNN Category 5 Model for Epoch 9
# Loss:  0.7627882287345392
#
# Training GNN Category 6 Model for Epoch 0
# Loss:  1.0265400175098207
#
# Training GNN Category 6 Model for Epoch 1
# Loss:  0.7969366895401342
#
# Training GNN Category 6 Model for Epoch 2
# Loss:  0.7733820969762147
#
# Training GNN Category 6 Model for Epoch 3
# Loss:  0.7677830975742155
#
# Training GNN Category 6 Model for Epoch 4
# Loss:  0.7664463842646276
#
# Training GNN Category 6 Model for Epoch 5
# Loss:  0.7634597724155493
#
# Training GNN Category 6 Model for Epoch 6
# Loss:  0.7615930906491927
#
# Training GNN Category 6 Model for Epoch 7
# Loss:  0.762368455213453
#
# Training GNN Category 6 Model for Epoch 8
# Loss:  0.7609224150469106
#
# Training GNN Category 6 Model for Epoch 9
# Loss:  0.7614080074100413
#
# Training GNN Category 7 Model for Epoch 0
# Loss:  0.9996604369552805
#
# Training GNN Category 7 Model for Epoch 1
# Loss:  0.798984008290333
#
# Training GNN Category 7 Model for Epoch 2
# Loss:  0.7742471183492596
#
# Training GNN Category 7 Model for Epoch 3
# Loss:  0.7683561181151728
#
# Training GNN Category 7 Model for Epoch 4
# Loss:  0.7665599755697158
#
# Training GNN Category 7 Model for Epoch 5
# Loss:  0.7625362300312241
#
# Training GNN Category 7 Model for Epoch 6
# Loss:  0.7623455707637576
#
# Training GNN Category 7 Model for Epoch 7
# Loss:  0.7604940700008891
#
# Training GNN Category 7 Model for Epoch 8
# Loss:  0.7612573786316625
#
# Training GNN Category 7 Model for Epoch 9
# Loss:  0.7598843573572598
#
# Training GNN Category 8 Model for Epoch 0
# Loss:  0.9791330395209862
#
# Training GNN Category 8 Model for Epoch 1
# Loss:  0.7960415280886746
#
# Training GNN Category 8 Model for Epoch 2
# Loss:  0.7773459071728631
#
# Training GNN Category 8 Model for Epoch 3
# Loss:  0.7732910526795634
#
# Training GNN Category 8 Model for Epoch 4
# Loss:  0.767835673907736
#
# Training GNN Category 8 Model for Epoch 5
# Loss:  0.7656032353550369
#
# Training GNN Category 8 Model for Epoch 6
# Loss:  0.7627586642579618
#
# Training GNN Category 8 Model for Epoch 7
# Loss:  0.7622962203678246
#
# Training GNN Category 8 Model for Epoch 8
# Loss:  0.7636757805876107
#
# Training GNN Category 8 Model for Epoch 9
# Loss:  0.7625802330894054
#
# Training Catch all GNN Category Model for Epoch 0
# Epoch: 0, Loss: 1.401782751083374
# Training Catch all GNN Category Model for Epoch 1
# Epoch: 1, Loss: 1.3505182266235352
# Training Catch all GNN Category Model for Epoch 2
# Epoch: 2, Loss: 1.313563346862793
# Training Catch all GNN Category Model for Epoch 3
# Epoch: 3, Loss: 1.297235369682312
# Training Catch all GNN Category Model for Epoch 4
# Epoch: 4, Loss: 1.2770346403121948
# Training Catch all GNN Category Model for Epoch 5
# Epoch: 5, Loss: 1.2636100053787231
# Training Catch all GNN Category Model for Epoch 6
# Epoch: 6, Loss: 1.2398362159729004
# Training Catch all GNN Category Model for Epoch 7
# Epoch: 7, Loss: 1.2243170738220215
# Training Catch all GNN Category Model for Epoch 8
# Epoch: 8, Loss: 1.2049919366836548
# Training Catch all GNN Category Model for Epoch 9
# Epoch: 9, Loss: 1.1935195922851562
# Federated Learning Round Number: 1
#
# Running Setup on Client 051.txt
#
# Training GNN Category 0 Model for Epoch 0
# Loss:  0.781672180482202
#
# Training GNN Category 0 Model for Epoch 1
# Loss:  0.7748951450831312
#
# Training GNN Category 0 Model for Epoch 2
# Loss:  0.772025032855734
#
# Training GNN Category 0 Model for Epoch 3
# Loss:  0.7686627359353793
#
# Training GNN Category 0 Model for Epoch 4
# Loss:  0.7693072011094831
#
# Training GNN Category 0 Model for Epoch 5
# Loss:  0.7657159570667159
#
# Training GNN Category 0 Model for Epoch 6
# Loss:  0.7652246866733131
#
# Training GNN Category 0 Model for Epoch 7
# Loss:  0.7656034859654103
#
# Training GNN Category 0 Model for Epoch 8
# Loss:  0.764783403531635
#
# Training GNN Category 0 Model for Epoch 9
# Loss:  0.7685051014304213
#
# Training GNN Category 1 Model for Epoch 0
# Loss:  0.9134303493494934
#
# Training GNN Category 1 Model for Epoch 1
# Loss:  0.8947701339989
#
# Training GNN Category 1 Model for Epoch 2
# Loss:  0.8815977362793036
#
# Training GNN Category 1 Model for Epoch 3
# Loss:  0.8694119335640523
#
# Training GNN Category 1 Model for Epoch 4
# Loss:  0.8607414426086807
#
# Training GNN Category 1 Model for Epoch 5
# Loss:  0.8527689918803708
#
# Training GNN Category 1 Model for Epoch 6
# Loss:  0.8470023437211144
#
# Training GNN Category 1 Model for Epoch 7
# Loss:  0.8410314132612537
#
# Training GNN Category 1 Model for Epoch 8
# Loss:  0.8347795803002355
#
# Training GNN Category 1 Model for Epoch 9
# Loss:  0.8298880535757229
#
# Training GNN Category 2 Model for Epoch 0
# Loss:  0.7838798965667312
#
# Training GNN Category 2 Model for Epoch 1
# Loss:  0.7772910078766789
#
# Training GNN Category 2 Model for Epoch 2
# Loss:  0.771989727522155
#
# Training GNN Category 2 Model for Epoch 3
# Loss:  0.7708067974974786
#
# Training GNN Category 2 Model for Epoch 4
# Loss:  0.7665037396044524
#
# Training GNN Category 2 Model for Epoch 5
# Loss:  0.7655650745780024
#
# Training GNN Category 2 Model for Epoch 6
# Loss:  0.7658905080503009
#
# Training GNN Category 2 Model for Epoch 7
# Loss:  0.7685018278984922
#
# Training GNN Category 2 Model for Epoch 8
# Loss:  0.7637568021794294
#
# Training GNN Category 2 Model for Epoch 9
# Loss:  0.7647357317561229
#
# Training GNN Category 3 Model for Epoch 0
# Loss:  0.7825907588280635
#
# Training GNN Category 3 Model for Epoch 1
# Loss:  0.777974590046647
#
# Training GNN Category 3 Model for Epoch 2
# Loss:  0.7717739068505083
#
# Training GNN Category 3 Model for Epoch 3
# Loss:  0.7687473523171575
#
# Training GNN Category 3 Model for Epoch 4
# Loss:  0.7657665434552265
#
# Training GNN Category 3 Model for Epoch 5
# Loss:  0.7692623406332162
#
# Training GNN Category 3 Model for Epoch 6
# Loss:  0.7697983539225884
#
# Training GNN Category 3 Model for Epoch 7
# Loss:  0.7699577906637585
#
# Training GNN Category 3 Model for Epoch 8
# Loss:  0.7682023839971918
#
# Training GNN Category 3 Model for Epoch 9
# Loss:  0.7669189262147292
#
# Training GNN Category 4 Model for Epoch 0
# Loss:  0.940814036095548
#
# Training GNN Category 4 Model for Epoch 1
# Loss:  0.9092729115463815
#
# Training GNN Category 4 Model for Epoch 2
# Loss:  0.889751800365311
#
# Training GNN Category 4 Model for Epoch 3
# Loss:  0.8795604215649341
#
# Training GNN Category 4 Model for Epoch 4
# Loss:  0.8684479726912862
#
# Training GNN Category 4 Model for Epoch 5
# Loss:  0.8575492700003029
#
# Training GNN Category 4 Model for Epoch 6
# Loss:  0.8549972511141739
#
# Training GNN Category 4 Model for Epoch 7
# Loss:  0.8504274246694891
#
# Training GNN Category 4 Model for Epoch 8
# Loss:  0.8420632352800694
#
# Training GNN Category 4 Model for Epoch 9
# Loss:  0.8411611004840424
#
# Training GNN Category 5 Model for Epoch 0
# Loss:  0.7814163177292298
#
# Training GNN Category 5 Model for Epoch 1
# Loss:  0.7770039251269519
#
# Training GNN Category 5 Model for Epoch 2
# Loss:  0.7705917993075903
#
# Training GNN Category 5 Model for Epoch 3
# Loss:  0.7666095083428573
#
# Training GNN Category 5 Model for Epoch 4
# Loss:  0.7663146241134822
#
# Training GNN Category 5 Model for Epoch 5
# Loss:  0.7651659541885019
#
# Training GNN Category 5 Model for Epoch 6
# Loss:  0.7670167499532814
#
# Training GNN Category 5 Model for Epoch 7
# Loss:  0.7661347389291302
#
# Training GNN Category 5 Model for Epoch 8
# Loss:  0.7677867529091187
#
# Training GNN Category 5 Model for Epoch 9
# Loss:  0.7660369925069044
#
# Training GNN Category 6 Model for Epoch 0
# Loss:  0.7847254922516228
#
# Training GNN Category 6 Model for Epoch 1
# Loss:  0.780261221169472
#
# Training GNN Category 6 Model for Epoch 2
# Loss:  0.7786629788805958
#
# Training GNN Category 6 Model for Epoch 3
# Loss:  0.7773878603115612
#
# Training GNN Category 6 Model for Epoch 4
# Loss:  0.776031556778585
#
# Training GNN Category 6 Model for Epoch 5
# Loss:  0.7720283439675635
#
# Training GNN Category 6 Model for Epoch 6
# Loss:  0.7760461769970087
#
# Training GNN Category 6 Model for Epoch 7
# Loss:  0.77713077939757
#
# Training GNN Category 6 Model for Epoch 8
# Loss:  0.7736293345122832
#
# Training GNN Category 6 Model for Epoch 9
# Loss:  0.7687769556253531
#
# Training GNN Category 7 Model for Epoch 0
# Loss:  0.7804701812813828
#
# Training GNN Category 7 Model for Epoch 1
# Loss:  0.7760075935443034
#
# Training GNN Category 7 Model for Epoch 2
# Loss:  0.7690311182683315
#
# Training GNN Category 7 Model for Epoch 3
# Loss:  0.7731504944481364
#
# Training GNN Category 7 Model for Epoch 4
# Loss:  0.77057996366393
#
# Training GNN Category 7 Model for Epoch 5
# Loss:  0.7716845744656727
#
# Training GNN Category 7 Model for Epoch 6
# Loss:  0.7655039059904281
#
# Training GNN Category 7 Model for Epoch 7
# Loss:  0.7685987687994112
#
# Training GNN Category 7 Model for Epoch 8
# Loss:  0.7660002281815175
#
# Training GNN Category 7 Model for Epoch 9
# Loss:  0.767587328229497
#
# Training GNN Category 8 Model for Epoch 0
# Loss:  0.7861005342949359
#
# Training GNN Category 8 Model for Epoch 1
# Loss:  0.7815077433767493
#
# Training GNN Category 8 Model for Epoch 2
# Loss:  0.7755815474332317
#
# Training GNN Category 8 Model for Epoch 3
# Loss:  0.7712469623429851
#
# Training GNN Category 8 Model for Epoch 4
# Loss:  0.7703700877084552
#
# Training GNN Category 8 Model for Epoch 5
# Loss:  0.7689052923942475
#
# Training GNN Category 8 Model for Epoch 6
# Loss:  0.771205280993049
#
# Training GNN Category 8 Model for Epoch 7
# Loss:  0.7682584077339866
#
# Training GNN Category 8 Model for Epoch 8
# Loss:  0.7692686010720597
#
# Training GNN Category 8 Model for Epoch 9
# Loss:  0.7679783850217814
#
# Training Catch all GNN Category Model for Epoch 0
# Epoch: 0, Loss: 1.395370602607727
# Training Catch all GNN Category Model for Epoch 1
# Epoch: 1, Loss: 1.339192271232605
# Training Catch all GNN Category Model for Epoch 2
# Epoch: 2, Loss: 1.3008958101272583
# Training Catch all GNN Category Model for Epoch 3
# Epoch: 3, Loss: 1.2820844650268555
# Training Catch all GNN Category Model for Epoch 4
# Epoch: 4, Loss: 1.2648249864578247
# Training Catch all GNN Category Model for Epoch 5
# Epoch: 5, Loss: 1.2424614429473877
# Training Catch all GNN Category Model for Epoch 6
# Epoch: 6, Loss: 1.2266485691070557
# Training Catch all GNN Category Model for Epoch 7
# Epoch: 7, Loss: 1.208215355873108
# Training Catch all GNN Category Model for Epoch 8
# Epoch: 8, Loss: 1.1915844678878784
# Training Catch all GNN Category Model for Epoch 9
# Epoch: 9, Loss: 1.1694406270980835
# Running Setup on Client 501.txt
#
# Training GNN Category 0 Model for Epoch 0
# Loss:  0.7688628105611505
#
# Training GNN Category 0 Model for Epoch 1
# Loss:  0.7615503713935102
#
# Training GNN Category 0 Model for Epoch 2
# Loss:  0.7611797277238984
#
# Training GNN Category 0 Model for Epoch 3
# Loss:  0.7613949634812385
#
# Training GNN Category 0 Model for Epoch 4
# Loss:  0.7611642952140135
#
# Training GNN Category 0 Model for Epoch 5
# Loss:  0.7602488851740157
#
# Training GNN Category 0 Model for Epoch 6
# Loss:  0.7599569161307416
#
# Training GNN Category 0 Model for Epoch 7
# Loss:  0.7614080693021805
#
# Training GNN Category 0 Model for Epoch 8
# Loss:  0.7596313069308908
#
# Training GNN Category 0 Model for Epoch 9
# Loss:  0.7603619278774962
#
# Training GNN Category 1 Model for Epoch 0
# Loss:  0.9076171262681662
#
# Training GNN Category 1 Model for Epoch 1
# Loss:  0.8706836425114338
#
# Training GNN Category 1 Model for Epoch 2
# Loss:  0.8424048031119281
#
# Training GNN Category 1 Model for Epoch 3
# Loss:  0.8246636462022949
#
# Training GNN Category 1 Model for Epoch 4
# Loss:  0.810253242415797
#
# Training GNN Category 1 Model for Epoch 5
# Loss:  0.7999246856814912
#
# Training GNN Category 1 Model for Epoch 6
# Loss:  0.7928352200902417
#
# Training GNN Category 1 Model for Epoch 7
# Loss:  0.7868025536942789
#
# Training GNN Category 1 Model for Epoch 8
# Loss:  0.7848533886004863
#
# Training GNN Category 1 Model for Epoch 9
# Loss:  0.7830068780335899
#
# Training GNN Category 2 Model for Epoch 0
# Loss:  0.8210184993575024
#
# Training GNN Category 2 Model for Epoch 1
# Loss:  0.7906650696639468
#
# Training GNN Category 2 Model for Epoch 2
# Loss:  0.7826157472895905
#
# Training GNN Category 2 Model for Epoch 3
# Loss:  0.7766215968233076
#
# Training GNN Category 2 Model for Epoch 4
# Loss:  0.7724537207006502
#
# Training GNN Category 2 Model for Epoch 5
# Loss:  0.7706323448912702
#
# Training GNN Category 2 Model for Epoch 6
# Loss:  0.7708686187638374
#
# Training GNN Category 2 Model for Epoch 7
# Loss:  0.7694984686020966
#
# Training GNN Category 2 Model for Epoch 8
# Loss:  0.7702876292319165
#
# Training GNN Category 2 Model for Epoch 9
# Loss:  0.7704093321282488
#
# Training GNN Category 3 Model for Epoch 0
# Loss:  0.8038728127331445
#
# Training GNN Category 3 Model for Epoch 1
# Loss:  0.7840250677342835
#
# Training GNN Category 3 Model for Epoch 2
# Loss:  0.7728016862988636
#
# Training GNN Category 3 Model for Epoch 3
# Loss:  0.76873294629741
#
# Training GNN Category 3 Model for Epoch 4
# Loss:  0.7675008779764748
#
# Training GNN Category 3 Model for Epoch 5
# Loss:  0.7651528235612421
#
# Training GNN Category 3 Model for Epoch 6
# Loss:  0.7777669758935324
#
# Training GNN Category 3 Model for Epoch 7
# Loss:  0.7745321282103309
#
# Training GNN Category 3 Model for Epoch 8
# Loss:  0.7685930239534089
#
# Training GNN Category 3 Model for Epoch 9
# Loss:  0.7668354202261428
#
# Training GNN Category 4 Model for Epoch 0
# Loss:  0.8328838480219247
#
# Training GNN Category 4 Model for Epoch 1
# Loss:  0.789208929181437
#
# Training GNN Category 4 Model for Epoch 2
# Loss:  0.7782808233208998
#
# Training GNN Category 4 Model for Epoch 3
# Loss:  0.7734255653406202
#
# Training GNN Category 4 Model for Epoch 4
# Loss:  0.7724147472951884
#
# Training GNN Category 4 Model for Epoch 5
# Loss:  0.7737722651118553
#
# Training GNN Category 4 Model for Epoch 6
# Loss:  0.7729694331822354
#
# Training GNN Category 4 Model for Epoch 7
# Loss:  0.7712938791822682
#
# Training GNN Category 4 Model for Epoch 8
# Loss:  0.7684235133617235
#
# Training GNN Category 4 Model for Epoch 9
# Loss:  0.770871683432275
#
# Training GNN Category 5 Model for Epoch 0
# Loss:  0.8104016328897917
#
# Training GNN Category 5 Model for Epoch 1
# Loss:  0.7824575914396996
#
# Training GNN Category 5 Model for Epoch 2
# Loss:  0.7757248084879456
#
# Training GNN Category 5 Model for Epoch 3
# Loss:  0.7746092763992155
#
# Training GNN Category 5 Model for Epoch 4
# Loss:  0.7736361163897625
#
# Training GNN Category 5 Model for Epoch 5
# Loss:  0.7702087583016038
#
# Training GNN Category 5 Model for Epoch 6
# Loss:  0.7698804455736489
#
# Training GNN Category 5 Model for Epoch 7
# Loss:  0.7686675402027289
#
# Training GNN Category 5 Model for Epoch 8
# Loss:  0.7744194428650872
#
# Training GNN Category 5 Model for Epoch 9
# Loss:  0.7724969113794016
#
# Training GNN Category 6 Model for Epoch 0
# Loss:  0.8156350076058143
#
# Training GNN Category 6 Model for Epoch 1
# Loss:  0.7864724353923817
#
# Training GNN Category 6 Model for Epoch 2
# Loss:  0.7775310928353715
#
# Training GNN Category 6 Model for Epoch 3
# Loss:  0.7715099000120276
#
# Training GNN Category 6 Model for Epoch 4
# Loss:  0.7688807104688614
#
# Training GNN Category 6 Model for Epoch 5
# Loss:  0.7673403294308745
#
# Training GNN Category 6 Model for Epoch 6
# Loss:  0.7735275531689835
#
# Training GNN Category 6 Model for Epoch 7
# Loss:  0.7715595259110588
#
# Training GNN Category 6 Model for Epoch 8
# Loss:  0.7686852522735228
#
# Training GNN Category 6 Model for Epoch 9
# Loss:  0.7670036666015844
#
# Training GNN Category 7 Model for Epoch 0
# Loss:  0.8048513632082036
#
# Training GNN Category 7 Model for Epoch 1
# Loss:  0.782039529153636
#
# Training GNN Category 7 Model for Epoch 2
# Loss:  0.7751506402269626
#
# Training GNN Category 7 Model for Epoch 3
# Loss:  0.7742090052177395
#
# Training GNN Category 7 Model for Epoch 4
# Loss:  0.77201709728913
#
# Training GNN Category 7 Model for Epoch 5
# Loss:  0.770609249614163
#
# Training GNN Category 7 Model for Epoch 6
# Loss:  0.7700482792347599
#
# Training GNN Category 7 Model for Epoch 7
# Loss:  0.7691567176043984
#
# Training GNN Category 7 Model for Epoch 8
# Loss:  0.7659124637692482
#
# Training GNN Category 7 Model for Epoch 9
# Loss:  0.767524521085203
#
# Training GNN Category 8 Model for Epoch 0
# Loss:  0.8078685549847671
#
# Training GNN Category 8 Model for Epoch 1
# Loss:  0.7852448623164322
#
# Training GNN Category 8 Model for Epoch 2
# Loss:  0.7770370886356993
#
# Training GNN Category 8 Model for Epoch 3
# Loss:  0.7721274598665662
#
# Training GNN Category 8 Model for Epoch 4
# Loss:  0.7715446878886193
#
# Training GNN Category 8 Model for Epoch 5
# Loss:  0.7738492709327323
#
# Training GNN Category 8 Model for Epoch 6
# Loss:  0.7715914004694434
#
# Training GNN Category 8 Model for Epoch 7
# Loss:  0.7682388176043867
#
# Training GNN Category 8 Model for Epoch 8
# Loss:  0.7668618862717989
#
# Training GNN Category 8 Model for Epoch 9
# Loss:  0.769045793708063
#
# Training Catch all GNN Category Model for Epoch 0
# Epoch: 0, Loss: 1.4033138751983643
# Training Catch all GNN Category Model for Epoch 1
# Epoch: 1, Loss: 1.3565436601638794
# Training Catch all GNN Category Model for Epoch 2
# Epoch: 2, Loss: 1.315985918045044
# Training Catch all GNN Category Model for Epoch 3
# Epoch: 3, Loss: 1.3006783723831177
# Training Catch all GNN Category Model for Epoch 4
# Epoch: 4, Loss: 1.2935636043548584
# Training Catch all GNN Category Model for Epoch 5
# Epoch: 5, Loss: 1.2622332572937012
# Training Catch all GNN Category Model for Epoch 6
# Epoch: 6, Loss: 1.2517589330673218
# Training Catch all GNN Category Model for Epoch 7
# Epoch: 7, Loss: 1.2373369932174683
# Training Catch all GNN Category Model for Epoch 8
# Epoch: 8, Loss: 1.2220075130462646
# Training Catch all GNN Category Model for Epoch 9
# Epoch: 9, Loss: 1.2051692008972168
# Running Setup on Client 201.txt
#
# Training GNN Category 0 Model for Epoch 0
# Loss:  0.7634738904563688
#
# Training GNN Category 0 Model for Epoch 1
# Loss:  0.7606762708622392
#
# Training GNN Category 0 Model for Epoch 2
# Loss:  0.7622024056707057
#
# Training GNN Category 0 Model for Epoch 3
# Loss:  0.7604216719797281
#
# Training GNN Category 0 Model for Epoch 4
# Loss:  0.7593992053997269
#
# Training GNN Category 0 Model for Epoch 5
# Loss:  0.7587714814180717
#
# Training GNN Category 0 Model for Epoch 6
# Loss:  0.7590366508862207
#
# Training GNN Category 0 Model for Epoch 7
# Loss:  0.7597368738160258
#
# Training GNN Category 0 Model for Epoch 8
# Loss:  0.7598104410271527
#
# Training GNN Category 0 Model for Epoch 9
# Loss:  0.7603961402773384
#
# Training GNN Category 1 Model for Epoch 0
# Loss:  0.7845409254622068
#
# Training GNN Category 1 Model for Epoch 1
# Loss:  0.7639912105820503
#
# Training GNN Category 1 Model for Epoch 2
# Loss:  0.7608015716194338
#
# Training GNN Category 1 Model for Epoch 3
# Loss:  0.7602115586823963
#
# Training GNN Category 1 Model for Epoch 4
# Loss:  0.7623643513126334
#
# Training GNN Category 1 Model for Epoch 5
# Loss:  0.7612924341162749
#
# Training GNN Category 1 Model for Epoch 6
# Loss:  0.759378374551644
#
# Training GNN Category 1 Model for Epoch 7
# Loss:  0.7601330198911969
#
# Training GNN Category 1 Model for Epoch 8
# Loss:  0.7605502374261879
#
# Training GNN Category 1 Model for Epoch 9
# Loss:  0.7596000028015922
#
# Training GNN Category 2 Model for Epoch 0
# Loss:  0.7928889939200958
#
# Training GNN Category 2 Model for Epoch 1
# Loss:  0.7714228388740123
#
# Training GNN Category 2 Model for Epoch 2
# Loss:  0.7670217410948588
#
# Training GNN Category 2 Model for Epoch 3
# Loss:  0.7653526917847506
#
# Training GNN Category 2 Model for Epoch 4
# Loss:  0.7643121556986989
#
# Training GNN Category 2 Model for Epoch 5
# Loss:  0.7647783662197816
#
# Training GNN Category 2 Model for Epoch 6
# Loss:  0.7670281801865855
#
# Training GNN Category 2 Model for Epoch 7
# Loss:  0.765381507484381
#
# Training GNN Category 2 Model for Epoch 8
# Loss:  0.7633430444388031
#
# Training GNN Category 2 Model for Epoch 9
# Loss:  0.7635901509102608
#
# Training GNN Category 3 Model for Epoch 0
# Loss:  0.7779487026449714
#
# Training GNN Category 3 Model for Epoch 1
# Loss:  0.7639110917319719
#
# Training GNN Category 3 Model for Epoch 2
# Loss:  0.7625164432189719
#
# Training GNN Category 3 Model for Epoch 3
# Loss:  0.7630500545683434
#
# Training GNN Category 3 Model for Epoch 4
# Loss:  0.7626709507239898
#
# Training GNN Category 3 Model for Epoch 5
# Loss:  0.7622019736955882
#
# Training GNN Category 3 Model for Epoch 6
# Loss:  0.7607812847707747
#
# Training GNN Category 3 Model for Epoch 7
# Loss:  0.7617152042840999
#
# Training GNN Category 3 Model for Epoch 8
# Loss:  0.7605289882741413
#
# Training GNN Category 3 Model for Epoch 9
# Loss:  0.762461166869844
#
# Training GNN Category 4 Model for Epoch 0
# Loss:  0.7750141767188495
#
# Training GNN Category 4 Model for Epoch 1
# Loss:  0.7610224926901608
#
# Training GNN Category 4 Model for Epoch 2
# Loss:  0.7612803326552234
#
# Training GNN Category 4 Model for Epoch 3
# Loss:  0.759507884629353
#
# Training GNN Category 4 Model for Epoch 4
# Loss:  0.7599647478766
#
# Training GNN Category 4 Model for Epoch 5
# Loss:  0.7604084796591469
#
# Training GNN Category 4 Model for Epoch 6
# Loss:  0.7596850795120436
#
# Training GNN Category 4 Model for Epoch 7
# Loss:  0.7606164318049895
#
# Training GNN Category 4 Model for Epoch 8
# Loss:  0.7600002117567414
#
# Training GNN Category 4 Model for Epoch 9
# Loss:  0.7600438525326523
#
# Training GNN Category 5 Model for Epoch 0
# Loss:  0.7655564810922225
#
# Training GNN Category 5 Model for Epoch 1
# Loss:  0.7613613210951411
#
# Training GNN Category 5 Model for Epoch 2
# Loss:  0.7601303278638267
#
# Training GNN Category 5 Model for Epoch 3
# Loss:  0.7622010236592573
#
# Training GNN Category 5 Model for Epoch 4
# Loss:  0.7591466675713613
#
# Training GNN Category 5 Model for Epoch 5
# Loss:  0.7594125777449973
#
# Training GNN Category 5 Model for Epoch 6
# Loss:  0.7610945699572412
#
# Training GNN Category 5 Model for Epoch 7
# Loss:  0.7599425468128403
#
# Training GNN Category 5 Model for Epoch 8
# Loss:  0.7600244463481192
#
# Training GNN Category 5 Model for Epoch 9
# Loss:  0.7590140029277368
#
# Training GNN Category 6 Model for Epoch 0
# Loss:  0.766753387176888
#
# Training GNN Category 6 Model for Epoch 1
# Loss:  0.7606934379035671
#
# Training GNN Category 6 Model for Epoch 2
# Loss:  0.7597693605509344
#
# Training GNN Category 6 Model for Epoch 3
# Loss:  0.7600065467991073
#
# Training GNN Category 6 Model for Epoch 4
# Loss:  0.7610190616003141
#
# Training GNN Category 6 Model for Epoch 5
# Loss:  0.7606139566291586
#
# Training GNN Category 6 Model for Epoch 6
# Loss:  0.7581620929174319
#
# Training GNN Category 6 Model for Epoch 7
# Loss:  0.7597492103376908
#
# Training GNN Category 6 Model for Epoch 8
# Loss:  0.7609495152642789
#
# Training GNN Category 6 Model for Epoch 9
# Loss:  0.7593753272207044
#
# Training GNN Category 7 Model for Epoch 0
# Loss:  0.7631087585443644
#
# Training GNN Category 7 Model for Epoch 1
# Loss:  0.7598110348361996
#
# Training GNN Category 7 Model for Epoch 2
# Loss:  0.7602220862078565
#
# Training GNN Category 7 Model for Epoch 3
# Loss:  0.7600976051534043
#
# Training GNN Category 7 Model for Epoch 4
# Loss:  0.7596588555249384
#
# Training GNN Category 7 Model for Epoch 5
# Loss:  0.7607651059997974
#
# Training GNN Category 7 Model for Epoch 6
# Loss:  0.7597801940676286
#
# Training GNN Category 7 Model for Epoch 7
# Loss:  0.7592979962153534
#
# Training GNN Category 7 Model for Epoch 8
# Loss:  0.7602881396551687
#
# Training GNN Category 7 Model for Epoch 9
# Loss:  0.7597973331731708
#
# Training GNN Category 8 Model for Epoch 0
# Loss:  0.766534306620691
#
# Training GNN Category 8 Model for Epoch 1
# Loss:  0.7619409665343126
#
# Training GNN Category 8 Model for Epoch 2
# Loss:  0.7611947612129293
#
# Training GNN Category 8 Model for Epoch 3
# Loss:  0.760464260384424
#
# Training GNN Category 8 Model for Epoch 4
# Loss:  0.7639522369704016
#
# Training GNN Category 8 Model for Epoch 5
# Loss:  0.7601333040638066
#
# Training GNN Category 8 Model for Epoch 6
# Loss:  0.7599232578351586
#
# Training GNN Category 8 Model for Epoch 7
# Loss:  0.760409516980315
#
# Training GNN Category 8 Model for Epoch 8
# Loss:  0.7600893084401678
#
# Training GNN Category 8 Model for Epoch 9
# Loss:  0.7603721056853735
#
# Training Catch all GNN Category Model for Epoch 0
# Epoch: 0, Loss: 1.4056957960128784
# Training Catch all GNN Category Model for Epoch 1
# Epoch: 1, Loss: 1.3631632328033447
# Training Catch all GNN Category Model for Epoch 2
# Epoch: 2, Loss: 1.315205454826355
# Training Catch all GNN Category Model for Epoch 3
# Epoch: 3, Loss: 1.3018728494644165
# Training Catch all GNN Category Model for Epoch 4
# Epoch: 4, Loss: 1.2864646911621094
# Training Catch all GNN Category Model for Epoch 5
# Epoch: 5, Loss: 1.2597256898880005
# Training Catch all GNN Category Model for Epoch 6
# Epoch: 6, Loss: 1.2457993030548096
# Training Catch all GNN Category Model for Epoch 7
# Epoch: 7, Loss: 1.2284494638442993
# Training Catch all GNN Category Model for Epoch 8
# Epoch: 8, Loss: 1.2118034362792969
# Training Catch all GNN Category Model for Epoch 9
# Epoch: 9, Loss: 1.1946816444396973
# Federated Learning Round Number: 2
#
# Running Setup on Client 051.txt
#
# Training GNN Category 0 Model for Epoch 0
# Loss:  0.77531848932612
#
# Training GNN Category 0 Model for Epoch 1
# Loss:  0.7704016308443447
#
# Training GNN Category 0 Model for Epoch 2
# Loss:  0.7685661301472638
#
# Training GNN Category 0 Model for Epoch 3
# Loss:  0.765561722247881
#
# Training GNN Category 0 Model for Epoch 4
# Loss:  0.763798543485985
#
# Training GNN Category 0 Model for Epoch 5
# Loss:  0.7648775323243143
#
# Training GNN Category 0 Model for Epoch 6
# Loss:  0.7655605984717697
#
# Training GNN Category 0 Model for Epoch 7
# Loss:  0.7648370376772431
#
# Training GNN Category 0 Model for Epoch 8
# Loss:  0.7639298784686593
#
# Training GNN Category 0 Model for Epoch 9
# Loss:  0.7654672238088178
#
# Training GNN Category 1 Model for Epoch 0
# Loss:  0.8162819652219339
#
# Training GNN Category 1 Model for Epoch 1
# Loss:  0.8123449106160716
#
# Training GNN Category 1 Model for Epoch 2
# Loss:  0.8062517686836265
#
# Training GNN Category 1 Model for Epoch 3
# Loss:  0.8040521496561803
#
# Training GNN Category 1 Model for Epoch 4
# Loss:  0.8007161964420361
#
# Training GNN Category 1 Model for Epoch 5
# Loss:  0.7967760086648853
#
# Training GNN Category 1 Model for Epoch 6
# Loss:  0.7947825353248188
#
# Training GNN Category 1 Model for Epoch 7
# Loss:  0.7935263766705113
#
# Training GNN Category 1 Model for Epoch 8
# Loss:  0.7923465913071444
#
# Training GNN Category 1 Model for Epoch 9
# Loss:  0.7911322328056222
#
# Training GNN Category 2 Model for Epoch 0
# Loss:  0.773597934864414
#
# Training GNN Category 2 Model for Epoch 1
# Loss:  0.7729878865111035
#
# Training GNN Category 2 Model for Epoch 2
# Loss:  0.7676295096651231
#
# Training GNN Category 2 Model for Epoch 3
# Loss:  0.7681256889904088
#
# Training GNN Category 2 Model for Epoch 4
# Loss:  0.7662129459288876
#
# Training GNN Category 2 Model for Epoch 5
# Loss:  0.7661288980726297
#
# Training GNN Category 2 Model for Epoch 6
# Loss:  0.7640191412907539
#
# Training GNN Category 2 Model for Epoch 7
# Loss:  0.7695398279306112
#
# Training GNN Category 2 Model for Epoch 8
# Loss:  0.768637429858683
#
# Training GNN Category 2 Model for Epoch 9
# Loss:  0.7718116659291873
#
# Training GNN Category 3 Model for Epoch 0
# Loss:  0.7721058113816277
#
# Training GNN Category 3 Model for Epoch 1
# Loss:  0.771886691148593
#
# Training GNN Category 3 Model for Epoch 2
# Loss:  0.7691536133606068
#
# Training GNN Category 3 Model for Epoch 3
# Loss:  0.7668791850987761
#
# Training GNN Category 3 Model for Epoch 4
# Loss:  0.7685671160307732
#
# Training GNN Category 3 Model for Epoch 5
# Loss:  0.768038597270897
#
# Training GNN Category 3 Model for Epoch 6
# Loss:  0.7692650115051634
#
# Training GNN Category 3 Model for Epoch 7
# Loss:  0.7712040299720987
#
# Training GNN Category 3 Model for Epoch 8
# Loss:  0.7685779451092466
#
# Training GNN Category 3 Model for Epoch 9
# Loss:  0.7698118170243092
#
# Training GNN Category 4 Model for Epoch 0
# Loss:  0.8465285837706126
#
# Training GNN Category 4 Model for Epoch 1
# Loss:  0.8486408215740715
#
# Training GNN Category 4 Model for Epoch 2
# Loss:  0.84445033812575
#
# Training GNN Category 4 Model for Epoch 3
# Loss:  0.835498440593174
#
# Training GNN Category 4 Model for Epoch 4
# Loss:  0.8319649933987099
#
# Training GNN Category 4 Model for Epoch 5
# Loss:  0.8316475672904975
#
# Training GNN Category 4 Model for Epoch 6
# Loss:  0.8261272144473942
#
# Training GNN Category 4 Model for Epoch 7
# Loss:  0.8226888065147578
#
# Training GNN Category 4 Model for Epoch 8
# Loss:  0.8239103604062735
#
# Training GNN Category 4 Model for Epoch 9
# Loss:  0.8213946579063158
#
# Training GNN Category 5 Model for Epoch 0
# Loss:  0.7696516630839286
#
# Training GNN Category 5 Model for Epoch 1
# Loss:  0.7678117013949335
#
# Training GNN Category 5 Model for Epoch 2
# Loss:  0.7644102429317207
#
# Training GNN Category 5 Model for Epoch 3
# Loss:  0.7631008397696446
#
# Training GNN Category 5 Model for Epoch 4
# Loss:  0.7626059954148043
#
# Training GNN Category 5 Model for Epoch 5
# Loss:  0.7617963975207677
#
# Training GNN Category 5 Model for Epoch 6
# Loss:  0.7628809453872752
#
# Training GNN Category 5 Model for Epoch 7
# Loss:  0.7630209711511815
#
# Training GNN Category 5 Model for Epoch 8
# Loss:  0.7649830434628461
#
# Training GNN Category 5 Model for Epoch 9
# Loss:  0.7674253554279115
#
# Training GNN Category 6 Model for Epoch 0
# Loss:  0.7766555998161548
#
# Training GNN Category 6 Model for Epoch 1
# Loss:  0.7742141027400296
#
# Training GNN Category 6 Model for Epoch 2
# Loss:  0.7696526167278043
#
# Training GNN Category 6 Model for Epoch 3
# Loss:  0.7674194049736983
#
# Training GNN Category 6 Model for Epoch 4
# Loss:  0.7678428208063866
#
# Training GNN Category 6 Model for Epoch 5
# Loss:  0.7686187402704882
#
# Training GNN Category 6 Model for Epoch 6
# Loss:  0.7679238905549035
#
# Training GNN Category 6 Model for Epoch 7
# Loss:  0.7654691421377519
#
# Training GNN Category 6 Model for Epoch 8
# Loss:  0.7676490996514582
#
# ...
# Loss:  0.7635618674543563
#
# Training GNN Category 7 Model for Epoch 9
# Loss:  0.7673135191090853
#
# Training GNN Category 8 Model for Epoch 0
# Loss:  0.7746710024811633
#
# Training GNN Category 8 Model for Epoch 1
# Loss:  0.773228745674418
#
# Training GNN Category 8 Model for Epoch 2
# Loss:  0.7695898104420541
#
# Training GNN Category 8 Model for Epoch 3
# Loss:  0.7676442368397542
#
# Training GNN Category 8 Model for Epoch 4
# Loss:  0.7672753849906782
#
# Training GNN Category 8 Model for Epoch 5
# Loss:  0.7662883286254215
#
# Training GNN Category 8 Model for Epoch 6
# Loss:  0.7688165495519368
#
# Training GNN Category 8 Model for Epoch 7
# Loss:  0.766544368129998
#
# Training GNN Category 8 Model for Epoch 8
# Loss:  0.7676196157176562
#
# Training GNN Category 8 Model for Epoch 9
# Loss:  0.7668097970945674
#
# Training Catch all GNN Category Model for Epoch 0
# Epoch: 0, Loss: 1.3957189321517944
# Training Catch all GNN Category Model for Epoch 1
# Epoch: 1, Loss: 1.3399701118469238
# Training Catch all GNN Category Model for Epoch 2
# Epoch: 2, Loss: 1.3068652153015137
# Training Catch all GNN Category Model for Epoch 3
# Epoch: 3, Loss: 1.2843708992004395
# Training Catch all GNN Category Model for Epoch 4
# Epoch: 4, Loss: 1.2602920532226562
# Training Catch all GNN Category Model for Epoch 5
# Epoch: 5, Loss: 1.2403650283813477
# Training Catch all GNN Category Model for Epoch 6
# Epoch: 6, Loss: 1.227333903312683
# Training Catch all GNN Category Model for Epoch 7
# Epoch: 7, Loss: 1.2039239406585693
# Training Catch all GNN Category Model for Epoch 8
# Epoch: 8, Loss: 1.189906358718872
# Training Catch all GNN Category Model for Epoch 9
# Epoch: 9, Loss: 1.1694083213806152
# Running Setup on Client 501.txt
#
# Training GNN Category 0 Model for Epoch 0
# Loss:  0.7625039296093681
#
# Training GNN Category 0 Model for Epoch 1
# Loss:  0.7608746257725978
#
# Training GNN Category 0 Model for Epoch 2
# Loss:  0.7612265467188787
#
# Training GNN Category 0 Model for Epoch 3
# Loss:  0.7612989545455074
#
# Training GNN Category 0 Model for Epoch 4
# Loss:  0.7607766194446278
#
# Training GNN Category 0 Model for Epoch 5
# Loss:  0.7610173995771837
#
# Training GNN Category 0 Model for Epoch 6
# Loss:  0.761978040409046
#
# Training GNN Category 0 Model for Epoch 7
# Loss:  0.7647113730648941
#
# Training GNN Category 0 Model for Epoch 8
# Loss:  0.7606795582183125
#
# Training GNN Category 0 Model for Epoch 9
# Loss:  0.7599231407563977
#
# Training GNN Category 1 Model for Epoch 0
# Loss:  0.8014017357081027
#
# Training GNN Category 1 Model for Epoch 1
# Loss:  0.7962114616388383
#
# Training GNN Category 1 Model for Epoch 2
# Loss:  0.7847442526138148
#
# Training GNN Category 1 Model for Epoch 3
# Loss:  0.7823654024112826
#
# Training GNN Category 1 Model for Epoch 4
# Loss:  0.7796943580950992
#
# Training GNN Category 1 Model for Epoch 5
# Loss:  0.7749374675703568
#
# Training GNN Category 1 Model for Epoch 6
# Loss:  0.7725864614034854
#
# Training GNN Category 1 Model for Epoch 7
# Loss:  0.7715467833623688
#
# Training GNN Category 1 Model for Epoch 8
# Loss:  0.7716742002881481
#
# Training GNN Category 1 Model for Epoch 9
# Loss:  0.7693747666422148
#
# Training GNN Category 2 Model for Epoch 0
# Loss:  0.7866212578585182
#
# Training GNN Category 2 Model for Epoch 1
# Loss:  0.7772567612041537
#
# Training GNN Category 2 Model for Epoch 2
# Loss:  0.7725787823470072
#
# Training GNN Category 2 Model for Epoch 3
# Loss:  0.7704487198283677
#
# Training GNN Category 2 Model for Epoch 4
# Loss:  0.7689892021136538
#
# Training GNN Category 2 Model for Epoch 5
# Loss:  0.7682626160630897
#
# Training GNN Category 2 Model for Epoch 6
# Loss:  0.7675690069655284
#
# Training GNN Category 2 Model for Epoch 7
# Loss:  0.7686439715893493
#
# Training GNN Category 2 Model for Epoch 8
# Loss:  0.770900125500951
#
# Training GNN Category 2 Model for Epoch 9
# Loss:  0.7711579071417679
#
# Training GNN Category 3 Model for Epoch 0
# Loss:  0.7770246694086989
#
# Training GNN Category 3 Model for Epoch 1
# Loss:  0.7717552926290699
#
# Training GNN Category 3 Model for Epoch 2
# Loss:  0.7672079889351012
#
# Training GNN Category 3 Model for Epoch 3
# Loss:  0.7661345500565762
#
# Training GNN Category 3 Model for Epoch 4
# Loss:  0.764652217317553
#
# Training GNN Category 3 Model for Epoch 5
# Loss:  0.7679685946649116
#
# Training GNN Category 3 Model for Epoch 6
# Loss:  0.7669689290209505
#
# Training GNN Category 3 Model for Epoch 7
# Loss:  0.767113619241691
#
# Training GNN Category 3 Model for Epoch 8
# Loss:  0.7682120422734302
#
# Training GNN Category 3 Model for Epoch 9
# Loss:  0.7659113524961033
#
# Training GNN Category 4 Model for Epoch 0
# Loss:  0.7811160311816453
#
# Training GNN Category 4 Model for Epoch 1
# Loss:  0.7731688299943693
#
# Training GNN Category 4 Model for Epoch 2
# Loss:  0.7695443887882878
#
# Training GNN Category 4 Model for Epoch 3
# Loss:  0.7678370897059806
#
# Training GNN Category 4 Model for Epoch 4
# Loss:  0.7691424892776604
#
# Training GNN Category 4 Model for Epoch 5
# Loss:  0.7673917886275955
#
# Training GNN Category 4 Model for Epoch 6
# Loss:  0.7682926456156268
#
# Training GNN Category 4 Model for Epoch 7
# Loss:  0.767032372248118
#
# Training GNN Category 4 Model for Epoch 8
# Loss:  0.7692160649559568
#
# Training GNN Category 4 Model for Epoch 9
# Loss:  0.7694385556146602
#
# Training GNN Category 5 Model for Epoch 0
# Loss:  0.7924321893905278
#
# Training GNN Category 5 Model for Epoch 1
# Loss:  0.7761278009473261
#
# Training GNN Category 5 Model for Epoch 2
# Loss:  0.7721830476467336
#
# Training GNN Category 5 Model for Epoch 3
# Loss:  0.7705588409783855
#
# Training GNN Category 5 Model for Epoch 4
# Loss:  0.7705726088274277
#
# Training GNN Category 5 Model for Epoch 5
# Loss:  0.7684960776788081
#
# Training GNN Category 5 Model for Epoch 6
# Loss:  0.7672741291545316
#
# Training GNN Category 5 Model for Epoch 7
# Loss:  0.7672055277145508
#
# Training GNN Category 5 Model for Epoch 8
# Loss:  0.7677916498928278
#
# Training GNN Category 5 Model for Epoch 9
# Loss:  0.768753315332829
#
# Training GNN Category 6 Model for Epoch 0
# Loss:  0.7835904608655027
#
# Training GNN Category 6 Model for Epoch 1
# Loss:  0.7716414702202112
#
# Training GNN Category 6 Model for Epoch 2
# Loss:  0.7678376751677377
#
# Training GNN Category 6 Model for Epoch 3
# Loss:  0.7684389354135939
#
# Training GNN Category 6 Model for Epoch 4
# Loss:  0.7668602311235344
#
# Training GNN Category 6 Model for Epoch 5
# Loss:  0.7646144728300535
#
# Training GNN Category 6 Model for Epoch 6
# Loss:  0.7655167462755423
#
# Training GNN Category 6 Model for Epoch 7
# Loss:  0.766030357720728
#
# Training GNN Category 6 Model for Epoch 8
# Loss:  0.7687849415401197
#
# Training GNN Category 6 Model for Epoch 9
# Loss:  0.7695755701561
#
# Training GNN Category 7 Model for Epoch 0
# Loss:  0.7863289287259757
#
# Training GNN Category 7 Model for Epoch 1
# Loss:  0.7772452805023337
#
# Training GNN Category 7 Model for Epoch 2
# Loss:  0.7711009702715209
#
# Training GNN Category 7 Model for Epoch 3
# Loss:  0.7697136544485756
#
# Training GNN Category 7 Model for Epoch 4
# Loss:  0.7681513440682478
#
# Training GNN Category 7 Model for Epoch 5
# Loss:  0.766736193179358
#
# Training GNN Category 7 Model for Epoch 6
# Loss:  0.7662230924919966
#
# Training GNN Category 7 Model for Epoch 7
# Loss:  0.7696766633907617
#
# Training GNN Category 7 Model for Epoch 8
# Loss:  0.7669739454859962
#
# Training GNN Category 7 Model for Epoch 9
# Loss:  0.766721872277088
#
# Training GNN Category 8 Model for Epoch 0
# Loss:  0.7845584953334925
#
# Training GNN Category 8 Model for Epoch 1
# Loss:  0.7749182291087515
#
# Training GNN Category 8 Model for Epoch 2
# Loss:  0.7704670972842848
#
# Training GNN Category 8 Model for Epoch 3
# Loss:  0.7688422517316743
#
# Training GNN Category 8 Model for Epoch 4
# Loss:  0.7747071015690703
#
# Training GNN Category 8 Model for Epoch 5
# Loss:  0.774544034737268
#
# Training GNN Category 8 Model for Epoch 6
# Loss:  0.7711259510632436
#
# Training GNN Category 8 Model for Epoch 7
# Loss:  0.7682872077970696
#
# Training GNN Category 8 Model for Epoch 8
# Loss:  0.7664267107857572
#
# Training GNN Category 8 Model for Epoch 9
# Loss:  0.7657247263686291
#
# Training Catch all GNN Category Model for Epoch 0
# Epoch: 0, Loss: 1.3996862173080444
# Training Catch all GNN Category Model for Epoch 1
# Epoch: 1, Loss: 1.3491559028625488
# Training Catch all GNN Category Model for Epoch 2
# Epoch: 2, Loss: 1.327383279800415
# Training Catch all GNN Category Model for Epoch 3
# Epoch: 3, Loss: 1.3011654615402222
# Training Catch all GNN Category Model for Epoch 4
# Epoch: 4, Loss: 1.2874025106430054
# Training Catch all GNN Category Model for Epoch 5
# Epoch: 5, Loss: 1.2653939723968506
# Training Catch all GNN Category Model for Epoch 6
# Epoch: 6, Loss: 1.2548850774765015
# Training Catch all GNN Category Model for Epoch 7
# Epoch: 7, Loss: 1.2382793426513672
# Training Catch all GNN Category Model for Epoch 8
# Epoch: 8, Loss: 1.2260864973068237
# Training Catch all GNN Category Model for Epoch 9
# Epoch: 9, Loss: 1.2018249034881592
# Running Setup on Client 201.txt
#
# Training GNN Category 0 Model for Epoch 0
# Loss:  0.759815738420764
#
# Training GNN Category 0 Model for Epoch 1
# Loss:  0.7597333047073934
#
# Training GNN Category 0 Model for Epoch 2
# Loss:  0.7604929323398015
#
# Training GNN Category 0 Model for Epoch 3
# Loss:  0.7634413616870547
#
# Training GNN Category 0 Model for Epoch 4
# Loss:  0.7600001050519174
#
# Training GNN Category 0 Model for Epoch 5
# Loss:  0.760965081653654
#
# Training GNN Category 0 Model for Epoch 6
# Loss:  0.7584155666504663
#
# Training GNN Category 0 Model for Epoch 7
# Loss:  0.7633738015106655
#
# Training GNN Category 0 Model for Epoch 8
# Loss:  0.7614973924511178
#
# Training GNN Category 0 Model for Epoch 9
# Loss:  0.7581980088042476
#
# Training GNN Category 1 Model for Epoch 0
# Loss:  0.76131547938857
#
# Training GNN Category 1 Model for Epoch 1
# Loss:  0.75964363436065
#
# Training GNN Category 1 Model for Epoch 2
# Loss:  0.7588062571891666
#
# Training GNN Category 1 Model for Epoch 3
# Loss:  0.7603277921451309
#
# Training GNN Category 1 Model for Epoch 4
# Loss:  0.7593670734468632
#
# Training GNN Category 1 Model for Epoch 5
# Loss:  0.7593370240264918
#
# Training GNN Category 1 Model for Epoch 6
# Loss:  0.7593353340847392
#
# Training GNN Category 1 Model for Epoch 7
# Loss:  0.7591031604477481
#
# Training GNN Category 1 Model for Epoch 8
# Loss:  0.760445092619982
#
# Training GNN Category 1 Model for Epoch 9
# Loss:  0.7601737701984717
#
# Training GNN Category 2 Model for Epoch 0
# Loss:  0.7762187752387749
#
# Training GNN Category 2 Model for Epoch 1
# Loss:  0.7637595037249141
#
# Training GNN Category 2 Model for Epoch 2
# Loss:  0.7636988159046314
#
# Training GNN Category 2 Model for Epoch 3
# Loss:  0.7635620245235083
#
# Training GNN Category 2 Model for Epoch 4
# Loss:  0.764707987582893
#
# Training GNN Category 2 Model for Epoch 5
# Loss:  0.7637415530832264
#
# Training GNN Category 2 Model for Epoch 6
# Loss:  0.7624461845178688
#
# Training GNN Category 2 Model for Epoch 7
# Loss:  0.7643097047277103
#
# Training GNN Category 2 Model for Epoch 8
# Loss:  0.765859412142458
#
# Training GNN Category 2 Model for Epoch 9
# Loss:  0.7693093554565605
#
# Training GNN Category 3 Model for Epoch 0
# Loss:  0.7647139495996668
#
# Training GNN Category 3 Model for Epoch 1
# Loss:  0.760804602806651
#
# Training GNN Category 3 Model for Epoch 2
# Loss:  0.7617189593078856
#
# Training GNN Category 3 Model for Epoch 3
# Loss:  0.7637249579709687
#
# Training GNN Category 3 Model for Epoch 4
# Loss:  0.7605535751802776
#
# Training GNN Category 3 Model for Epoch 5
# Loss:  0.7598127685569217
#
# Training GNN Category 3 Model for Epoch 6
# Loss:  0.7613133097987735
#
# Training GNN Category 3 Model for Epoch 7
# Loss:  0.7616542685978538
#
# Training GNN Category 3 Model for Epoch 8
# Loss:  0.7615815832935605
#
# Training GNN Category 3 Model for Epoch 9
# Loss:  0.7613764309700869
#
# Training GNN Category 4 Model for Epoch 0
# Loss:  0.7608588187338547
#
# Training GNN Category 4 Model for Epoch 1
# Loss:  0.7599309965426975
#
# Training GNN Category 4 Model for Epoch 2
# Loss:  0.7598175806104895
#
# Training GNN Category 4 Model for Epoch 3
# Loss:  0.7599165671293806
#
# Training GNN Category 4 Model for Epoch 4
# Loss:  0.7621085161774801
#
# Training GNN Category 4 Model for Epoch 5
# Loss:  0.760073832173345
#
# Training GNN Category 4 Model for Epoch 6
# Loss:  0.7604930629722324
#
# Training GNN Category 4 Model for Epoch 7
# Loss:  0.759078138261903
#
# Training GNN Category 4 Model for Epoch 8
# Loss:  0.7607583996425558
#
# Training GNN Category 4 Model for Epoch 9
# Loss:  0.7606276737046423
#
# Training GNN Category 5 Model for Epoch 0
# Loss:  0.7602108468269249
#
# Training GNN Category 5 Model for Epoch 1
# Loss:  0.7602574643042003
#
# Training GNN Category 5 Model for Epoch 2
# Loss:  0.758919336054314
#
# Training GNN Category 5 Model for Epoch 3
# Loss:  0.7604305362941655
#
# Training GNN Category 5 Model for Epoch 4
# Loss:  0.7591287634756175
#
# Training GNN Category 5 Model for Epoch 5
# Loss:  0.7595542876228836
#
# Training GNN Category 5 Model for Epoch 6
# Loss:  0.7622991810844286
#
# Training GNN Category 5 Model for Epoch 7
# Loss:  0.7638341544961973
#
# Training GNN Category 5 Model for Epoch 8
# Loss:  0.7605556975939247
#
# Training GNN Category 5 Model for Epoch 9
# Loss:  0.7588540025339157
#
# Training GNN Category 6 Model for Epoch 0
# Loss:  0.7590824813140473
#
# Training GNN Category 6 Model for Epoch 1
# Loss:  0.7613188961276025
#
# Training GNN Category 6 Model for Epoch 2
# Loss:  0.7589858310757355
#
# Training GNN Category 6 Model for Epoch 3
# Loss:  0.7600075273015581
#
# Training GNN Category 6 Model for Epoch 4
# Loss:  0.7594751524119888
#
# Training GNN Category 6 Model for Epoch 5
# Loss:  0.7613840929877801
#
# Training GNN Category 6 Model for Epoch 6
# Loss:  0.7606926222090639
#
# Training GNN Category 6 Model for Epoch 7
# Loss:  0.7609269733995531
#
# Training GNN Category 6 Model for Epoch 8
# Loss:  0.7602444355725758
#
# Training GNN Category 6 Model for Epoch 9
# Loss:  0.7610429961228339
#
# Training GNN Category 7 Model for Epoch 0
# Loss:  0.7608121523949782
#
# Training GNN Category 7 Model for Epoch 1
# Loss:  0.7593791703165853
#
# Training GNN Category 7 Model for Epoch 2
# Loss:  0.7603934562536871
#
# Training GNN Category 7 Model for Epoch 3
# Loss:  0.7594150395708478
#
# Training GNN Category 7 Model for Epoch 4
# Loss:  0.7601660640965862
#
# Training GNN Category 7 Model for Epoch 5
# Loss:  0.7602207966500804
#
# Training GNN Category 7 Model for Epoch 6
# Loss:  0.7601111929076816
#
# Training GNN Category 7 Model for Epoch 7
# Loss:  0.7595238589356466
#
# Training GNN Category 7 Model for Epoch 8
# Loss:  0.7603482583848796
#
# Training GNN Category 7 Model for Epoch 9
# Loss:  0.7603367580627005
#
# Training GNN Category 8 Model for Epoch 0
# Loss:  0.761567766677945
#
# Training GNN Category 8 Model for Epoch 1
# Loss:  0.7587152455106975
#
# Training GNN Category 8 Model for Epoch 2
# Loss:  0.759962054776619
#
# Training GNN Category 8 Model for Epoch 3
# Loss:  0.7605224018052436
#
# Training GNN Category 8 Model for Epoch 4
# Loss:  0.7597799979150236
#
# Training GNN Category 8 Model for Epoch 5
# Loss:  0.7610692589409136
#
# Training GNN Category 8 Model for Epoch 6
# Loss:  0.7605972393244269
#
# Training GNN Category 8 Model for Epoch 7
# Loss:  0.7600381677921838
#
# Training GNN Category 8 Model for Epoch 8
# Loss:  0.7608319746248624
#
# Training GNN Category 8 Model for Epoch 9
# Loss:  0.7599279513806572
#
# Training Catch all GNN Category Model for Epoch 0
# Epoch: 0, Loss: 1.4062559604644775
# Training Catch all GNN Category Model for Epoch 1
# Epoch: 1, Loss: 1.348057746887207
# Training Catch all GNN Category Model for Epoch 2
# Epoch: 2, Loss: 1.3147159814834595
# Training Catch all GNN Category Model for Epoch 3
# Epoch: 3, Loss: 1.292026400566101
# Training Catch all GNN Category Model for Epoch 4
# Epoch: 4, Loss: 1.273260474205017
# Training Catch all GNN Category Model for Epoch 5
# Epoch: 5, Loss: 1.2582345008850098
# Training Catch all GNN Category Model for Epoch 6
# Epoch: 6, Loss: 1.241553783416748
# Training Catch all GNN Category Model for Epoch 7
# Epoch: 7, Loss: 1.2262409925460815
# Training Catch all GNN Category Model for Epoch 8
# Epoch: 8, Loss: 1.204217553138733
# Training Catch all GNN Category Model for Epoch 9
# Epoch: 9, Loss: 1.1862831115722656

# %%
data_cache_mal = {}

def load_test_data():
    global data_cache_mal
        
    for x in ['201','501','051']:
        path = f"Content_FL_Exp/eval_data/SysClient0{x}.systemia.com.txt"
        f = open(path)
        content = [json.loads(line) for line in f]
        docs,labels,edges,mapp,pids,idx_to_pid = prepare_graph(transform(content))
        data_cache_mal[x] = [docs,labels,edges,mapp,pids,idx_to_pid]

# %%
#load_data_test()

# %%
with open('Content_FL_Exp/optc_ensemble_mal.json', 'r') as f:
    data_cache_mal = json.load(f)

# %%
from collections import Counter

# %%
TP,FP,FN,TN = 0,0,0,0
FPL = set()
for data_id in ['201','501','051']:

    docs,labels,edges,mapp,pids,idx_to_pid = data_cache_mal[data_id]

    nodes_feat = []
    word2vec = Word2Vec.load(f"Content_FL_Exp/unified_word2vec.model")
    for x in docs:
        nodes_feat.append( infer(x,word2vec) ) 

    with open(f"gt_{data_id}.json", "r") as json_file:
        gt,acts,objs = json.load(json_file)  

    gt,acts,objs = set(gt),set(acts),set(objs)

    graph = Data(x=torch.tensor(nodes_feat,dtype=torch.float).to(device),y=torch.tensor(labels,dtype=torch.long).to(device), edge_index=torch.tensor(edges,dtype=torch.long).to(device))

    flag = torch.tensor([True]*graph.num_nodes, dtype=torch.bool)

    model = GCN().to(device)

    for m_n in range(num_of_ctg):
        if f"global{m_n}.pth" in os.listdir("Content_FL_Exp"): 
            model.load_state_dict(torch.load(f"Content_FL_Exp/global{m_n}.pth"))
            
        model.eval()
        out = model(graph.x, graph.edge_index)

        sorted, indices = out.sort(dim=1,descending=True)
        conf = (sorted[:,0] - sorted[:,1]) / sorted[:,0]
        conf = (conf - conf.min()) / conf.max()

        pred = indices[:,0]
        cond = (pred == graph.y) & (conf >= 0.7)
        flag[cond] = torch.logical_and(flag[cond], torch.tensor([False]*len(flag[cond]), dtype=torch.bool))

    index = utils.mask_to_index(flag).tolist()
    ids = set([mapp[x] for x in index])

    metrics = helper(set(ids),acts,objs,gt,edges,mapp) 
        
    fp = [i for i in range(len(mapp)) if mapp[i] in metrics[4] and labels[i] in [0,1,2]]
          
    TP = TP + metrics[0]
    FP = FP + len(fp)
    FN = FN + metrics[2]
    TN = TN + metrics[3]

print(f"Number of True Positives: {TP}")
print(f"Number of Fasle Positives: {FP}")
print(f"Number of False Negatives: {FN}")
print(f"Number of True Negatives: {TN}\n")

prec = TP / (TP + FP)
print(f"Precision: {prec}")

rec = TP / (TP + FN)
print(f"Recall: {rec}")

fscore = (2*prec*rec) / (prec + rec)
print(f"Fscore: {fscore}\n")
# Out:
# Number of True Positives: 615
# Number of Fasle Positives: 65
# Number of False Negatives: 35
# Number of True Negatives: 1287209
#
# Precision: 0.9044117647058824
# Recall: 0.9461538461538461
# Fscore: 0.9248120300751879
